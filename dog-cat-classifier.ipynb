# %%
import pandas as pd
import numpy as np
import torch
from torch import nn
from torch.autograd import Variable
import os
import torchvision
import sys
from torch.utils.data import DataLoader, Dataset
import torch.nn.functional as F
from torchvision import transforms
import keras
from keras import Sequential
from keras.layers import *
from keras import losses
import matplotlib.pyplot as plt
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# Extracting Data
data_transform = torchvision.transforms.Compose([
        transforms.Resize((67, 47)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.5, 0.5, 0.5],
                             std=[0.5, 0.5, 0.5])
    ])
data = torchvision.datasets.ImageFolder("./train", transform=data_transform)  
len(data)
# Out:
# 25000

# %%
# Creating DataLoader
train_loader = DataLoader(dataset=data, shuffle=True, batch_size=100)

# %%
shape = (100, 3, 67, 47)

def convert(array):
    return array.data.numpy().reshape(-1, 67, 47, 3)

input_shape = (67,47,3)

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=3, input_shape=input_shape, activation="relu"))
model.add(MaxPooling2D())
model.add(Conv2D(32, kernel_size=3, activation="relu"))
model.add(Flatten())
model.add(Dense(64, activation="relu"))
model.add(Dense(2, activation="softmax"))
model.compile(optimizer="adam", loss=losses.categorical_crossentropy, metrics=['acc'])

# %%
for feature, label in train_loader:
    feature = convert(feature)
    label = keras.utils.to_categorical(label.data.numpy(),2)
    history = model.fit(feature, label, epochs=5)
# Out:
# Epoch 1/5
# 100/100 [==============================] - 0s 4ms/step - loss: 0.8995 - acc: 0.5400
# Epoch 2/5
# 100/100 [==============================] - 0s 5ms/step - loss: 0.6907 - acc: 0.6000
# Epoch 3/5
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5606 - acc: 0.7700
# Epoch 4/5
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5033 - acc: 0.7800
# Epoch 5/5
# 100/100 [==============================] - 0s 5ms/step - loss: 0.4462 - acc: 0.8200
# Epoch 1/5
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5743 - acc: 0.7000
# Epoch 2/5
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5065 - acc: 0.7700
# Epoch 3/5
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3875 - acc: 0.8700
# Epoch 4/5
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3797 - acc: 0.8400
# Epoch 5/5
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2801 - acc: 0.9000
# Epoch 1/5
# ...

# %%
data.
# Out:
# ('./train/cat/cat.0.jpg', 0)
